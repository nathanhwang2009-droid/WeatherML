# %% [markdown]
# # Preprocessing Data

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))  # or "." depending on location

from scripts.preprocessed import preprocess_data

# %%
import pandas as pd

df = pd.read_csv("../data/raw/daily_weather.csv")
df_processed = preprocess_data(df, save_pickle=True, pickle_path="../data/processed/preprocessed_weather.pkl")
# Out:
# Preprocessed data file saved to: ../data/processed/preprocessed_weather.parquet
# /Users/nathanhwang/Coding/WeatherML/scripts/preprocessed.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_processed["time"] = pd.to_datetime(df_processed["time"])
# /Users/nathanhwang/Coding/WeatherML/scripts/preprocessed.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_processed["weather_code"] = df_processed["weather_code"].astype("category")

# %%
df = pd.read_pickle("../data/processed/preprocessed_weather.pkl")
df.head()
# Out:
#         time  temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# 0 2019-01-01                21.8                 6.5                 14.3
# 1 2019-01-02                22.6                 8.0                 14.6
# 2 2019-01-03                22.6                 7.8                 14.6
# 3 2019-01-04                22.2                 8.0                 14.7
# 4 2019-01-05                23.4                 9.9                 16.0
#
#    apparent_temperature_max  apparent_temperature_min  \
# 0                      20.9                       4.3
# 1                      21.7                       6.0
# 2                      21.2                       6.2
# 3                      21.6                       6.1
# 4                      21.5                       8.2
#
#    relative_humidity_2m_max  relative_humidity_2m_min  \
# 0                        94                        39
# 1                        95                        41
# ...

# %%
print(df.dtypes)
# Out:
# time                           datetime64[ns]
# temperature_2m_max                    float64
# temperature_2m_min                    float64
# temperature_2m_mean                   float64
# apparent_temperature_max              float64
# apparent_temperature_min              float64
# relative_humidity_2m_max                int64
# relative_humidity_2m_min                int64
# relative_humidity_2m_mean               int64
# wind_speed_10m_max                    float64
# wind_gusts_10m_max                    float64
# wind_direction_10m_dominant             int64
# precipitation_sum                     float64
# rain_sum                              float64
# snowfall_sum                          float64
# precipitation_hours                   float64
# shortwave_radiation_sum               float64
# sunshine_duration                     float64
# weather_code                            int64
# target                                float64
# dtype: object
